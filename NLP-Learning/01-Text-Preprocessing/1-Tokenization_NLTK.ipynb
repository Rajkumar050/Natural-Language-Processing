# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in C:\Users\Raj Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.9.4)
# Requirement already satisfied: click in C:\Users\Raj Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in C:\Users\Raj Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\Raj Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in C:\Users\Raj Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\Raj Kumar\AppData\Roaming\Python\Python312\site-packages (from click->nltk) (0.4.6)

# %%
corpus="""Hello . my name is Raj Kumar.
and my profession is coding.
"""

# %%
print(corpus)
# Out:
# Hello . my name is Raj Kumar.
# and my profession is coding.

# %%
##  Tokenization

import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Raj
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Raj
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
## Sentence-->paragraphs

from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

print(documents)
# Out:
# ['Hello .', 'my name is Raj Kumar.', 'and my profession is coding.']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello .
# my name is Raj Kumar.
# and my profession is coding.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  '.',
#  'my',
#  'name',
#  'is',
#  'Raj',
#  'Kumar',
#  '.',
#  'and',
#  'my',
#  'profession',
#  'is',
#  'coding',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', '.']
# ['my', 'name', 'is', 'Raj', 'Kumar', '.']
# ['and', 'my', 'profession', 'is', 'coding', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  '.',
#  'my',
#  'name',
#  'is',
#  'Raj',
#  'Kumar',
#  '.',
#  'and',
#  'my',
#  'profession',
#  'is',
#  'coding',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  '.',
#  'my',
#  'name',
#  'is',
#  'Raj',
#  'Kumar.',
#  'and',
#  'my',
#  'profession',
#  'is',
#  'coding',
#  '.']
