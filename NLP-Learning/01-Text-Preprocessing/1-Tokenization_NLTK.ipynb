# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in E:\ml_project1\venv\Lib\site-packages (from nltk) (8.4.0)
# Requirement already satisfied: joblib in E:\ml_project1\venv\Lib\site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Using cached regex-2026.5.9-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in E:\ml_project1\venv\Lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# Using cached regex-2026.5.9-cp314-cp314-win_amd64.whl (280 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, nltk
#
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    ---------------------------------------- 3/3 [nltk]
#
# Successfully installed nltk-3.9.4 regex-2026.5.9 tqdm-4.67.3
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored

# %%
corpus="""Hello . my name is Raj Kumar.
and my profession is coding.
"""

# %%
print(corpus)
# Out:
# Hello . my name is Raj Kumar.
# and my profession is coding.

# %%
##  Tokenization

import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Raj
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Raj
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
## Sentence-->paragraphs

from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

print(documents)
# Out:
# ['Hello .', 'my name is Raj Kumar.', 'and my profession is coding.']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello .
# my name is Raj Kumar.
# and my profession is coding.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  '.',
#  'my',
#  'name',
#  'is',
#  'Raj',
#  'Kumar',
#  '.',
#  'and',
#  'my',
#  'profession',
#  'is',
#  'coding',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', '.']
# ['my', 'name', 'is', 'Raj', 'Kumar', '.']
# ['and', 'my', 'profession', 'is', 'coding', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  '.',
#  'my',
#  'name',
#  'is',
#  'Raj',
#  'Kumar',
#  '.',
#  'and',
#  'my',
#  'profession',
#  'is',
#  'coding',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  '.',
#  'my',
#  'name',
#  'is',
#  'Raj',
#  'Kumar.',
#  'and',
#  'my',
#  'profession',
#  'is',
#  'coding',
#  '.']
